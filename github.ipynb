# %%
# show gh version
# !gh --version
# Out:
# /bin/bash: line 1: gh: command not found

# %%
# !cat ~/.ssh/authorized_keys
# Out:
# # Added by Google
# ssh-rsa  w3c_offical@mac

# %%
# !cat ~/.ssh/id_rsa.pub
# Out:
# ssh-rsa ... w3c_offical@instance-20260203-155747

# %%
# Create a public repository
# !gh repo create my-public-repo --public --description "A public repository"

# %%
# Create a private repository
# !gh repo create my-private-repo --private --description "A private repository"

# %%
# List repositories
# !source ~/.bashrc
# !gh repo list
# Out:
# ]11;?\]11;?\To get started with GitHub CLI, please run:  gh auth login
# Alternatively, populate the GH_TOKEN environment variable with a GitHub API authentication token.
